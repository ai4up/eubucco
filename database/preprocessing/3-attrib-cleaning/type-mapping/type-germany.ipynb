# %%
import os
import pandas as pd
import ast
import re

# %% [markdown]
# # create the mapping dictionary and Choose residental and non_residental

# %%
# xml = http://www.sig3d.org/codelists/Handbuch-SIG3D/building/2.0/CL-V1.0/_AbstractBuilding_function.xml
with open(r"D:\Nicola project\Nicola project\1\database\preprocessing\1_parsing\Germen\dictionary.txt",'r',encoding='utf-8') as f:
    dictionary =f.read()

# %%
map_dictionary = pd.DataFrame()
map_dictionary['type'] = re.findall(r"<gml:description>(.+?)</gml:description>\n", dictionary)
map_dictionary['code']= re.findall(r"<gml:name>(.+?)</gml:name>\n", dictionary)

# %%
# pip install deep-translator
from deep_translator import GoogleTranslator

# %%
map_dictionary['german_name'] = map_dictionary['type']

# %%
lst = []
for i in map_dictionary['type']:
    name = GoogleTranslator(source='auto', target='en').translate(i)
    lst.append(name)

# %%
map_dictionary['english_name'] = lst

# %%
map_dictionary
# Out:
#                                         type  code  \
# 0                                Wohngebäude  1000
# 1                                   Wohnhaus  1010
# 2                                   Wohnheim  1020
# 3                                 Kinderheim  1021
# 4                               Seniorenheim  1022
# ..                                       ...   ...
# 227                        Pflanzenschauhaus  3273
# 228  Gebäude für andere Erholungseinrichtung  3280
# 229                              Schutzhütte  3281
# 230        Touristisches Informationszentrum  3290
# 231  Nach Quellenlage nicht zu spezifizieren  9998
#
#                                  german_name  \
# 0                                Wohngebäude
# 1                                   Wohnhaus
# 2                                   Wohnheim
# 3                                 Kinderheim
# 4                               Seniorenheim
# ..                                       ...
# 227                        Pflanzenschauhaus
# 228  Gebäude für andere Erholungseinrichtung
# 229                              Schutzhütte
# 230        Touristisches Informationszentrum
# 231  Nach Quellenlage nicht zu spezifizieren
#
#                                english_name
# 0                      residential building
# 1                         residential house
# 2                                      dorm
# 3                           children's home
# 4                           retirement home
# ..                                      ...
# 227                        plant show house
# 228  Building for other recreation facility
# 229                                 shelter
# 230              Tourist information center
# 231    Cannot be specified based on sources
#
# [232 rows x 4 columns]

# %%
lst1 = []
for i in map_dictionary['english_name']:
    lst1.append(('residential' in i)|('Residential' in i)|('Mixed use building with housing' in i)\
               |('farmhouse' in i)|('Forsthaus' in i)|('Ferienhaus'in i)|('weekend house' in i)\
               |('Building for trade and services with housing'in i)\
               |('Building for trade and industry with living' in i))
map_dictionary['residential'] = lst1

# %%
map_dictionary
# Out:
#                                         type  code  \
# 0                                Wohngebäude  1000
# 1                                   Wohnhaus  1010
# 2                                   Wohnheim  1020
# 3                                 Kinderheim  1021
# 4                               Seniorenheim  1022
# ..                                       ...   ...
# 227                        Pflanzenschauhaus  3273
# 228  Gebäude für andere Erholungseinrichtung  3280
# 229                              Schutzhütte  3281
# 230        Touristisches Informationszentrum  3290
# 231  Nach Quellenlage nicht zu spezifizieren  9998
#
#                                  german_name  \
# 0                                Wohngebäude
# 1                                   Wohnhaus
# 2                                   Wohnheim
# 3                                 Kinderheim
# 4                               Seniorenheim
# ..                                       ...
# 227                        Pflanzenschauhaus
# 228  Gebäude für andere Erholungseinrichtung
# 229                              Schutzhütte
# 230        Touristisches Informationszentrum
# 231  Nach Quellenlage nicht zu spezifizieren
#
#                                english_name  residential
# 0                      residential building         True
# 1                         residential house         True
# 2                                      dorm        False
# 3                           children's home        False
# 4                           retirement home        False
# ..                                      ...          ...
# 227                        plant show house        False
# 228  Building for other recreation facility        False
# 229                                 shelter        False
# 230              Tourist information center        False
# 231    Cannot be specified based on sources        False
#
# [232 rows x 5 columns]

# %% [markdown]
# # go through all German attribute files and analyse the distributions in the different regions:

# %%
# extract string

def typecode(x):
    
    lst1 = []
    for i in x:
        a = i.split('.')[0][-4:]
        lst1.append(a)
    return(lst1)

# %%
path_directory = r"D:\Nicola project\Nicola project\mapping\jiawei"

for i in os.listdir(path_directory):   # os.listdir(path_directory)
        domain = os.path.abspath(path_directory) 
        region = i[:-4]
        print('region is {}'.format(region) )
        stat= os.path.join(domain,i) 
        if stat.endswith(".csv"):
            data = pd.read_csv(stat)
            
            not_have_type = data['type_source'].isna().sum()  # Count the number of nan values
            not_have_type = data['type_source'].isna().sum()  # Count the number of nan values
            have_type = len(data) - not_have_type
            ratio_of_have_type = have_type / len(data)
            print('num of have type is {}, num of non have type is {}, ratio of have type is {} '.format(have_type,not_have_type,ratio_of_have_type))

            data_copy = data.dropna(subset=['type_source']).copy()  #delete all NaN
            data_copy['type_source'] = data_copy['type_source'].astype(str)  #Change float to str
            data_copy['type_source'] =  typecode(data_copy['type_source'])
            
            df = data_copy.merge(map_dictionary,how='left',left_on='type_source' , right_on='code')
            
            num_residential = len(df[df['residential'] == True])
            num_non_residential = (len(df[df['residential'] == False]))
            ratio_of_residential = len(df[df['residential'] == True])/len(df['residential'])
            print('num of residential is {}, num of non-residential is {}, ratio of residential is {} '.format(num_residential,num_non_residential,ratio_of_residential))
            
            a = df['english_name'].value_counts()   # Count the number of type
            print(a)
            print('********************')
# Out:
# region is berlin-gov_attrib
# num of have type is 416620, num of non have type is 123506, ratio of have type is 0.7713385395259624
# num of residential is 97666, num of non-residential is 28833, ratio of residential is 0.2344246555614229
# Ferienhaus                                  75270
# farmhouse                                   20283
# shed                                        14211
# Sägewerk                                     8438
# converter                                    1715
# residential and administrative buildings     1625
# Kesselhaus                                   1174
# greenhouse                                    757
# Stall                                         535
# Car wash, car wash, car wash                  498
# residential and commercial buildings          330
# garbage bunker                                296
# Toilette                                      184
# Energy supply building                        183
# factory                                       175
# residential and office buildings              158
# substation                                    138
# barn                                          106
# Building of the sewage treatment plant         80
# Pump station                                   79
# farm buildings                                 75
# waterworks                                     57
# power station                                  37
# cold store                                     23
# pump station (not for water supply)            19
# water tank                                     19
# barn and stable                                17
# Waste incineration building                     9
# Gaswerk                                         7
# Barn for animal husbandry                       1
# Name: english_name, dtype: int64
# ********************
# region is brandenburg-gov_attrib
# num of have type is 2314099, num of non have type is 0, ratio of have type is 1.0
# num of residential is 764840, num of non-residential is 1542367, ratio of residential is 0.3305130852223695
# residential house                             731580
# Garage                                        320113
# Agricultural and forestry company building    242958
# Cannot be specified based on sources          236524
# Recreational buildings                        209976
#                                                ...
# Turbinenhaus                                       4
# Parliament                                         4
# Finanzamt                                          2
# farmhouse                                          1
# Sanatorium                                         1
# Name: english_name, Length: 141, dtype: int64
# ********************
# region is freiburg-gov_attrib
# num of have type is 57969, num of non have type is 0, ratio of have type is 1.0
# num of residential is 0, num of non-residential is 57969, ratio of residential is 0.0
# Cannot be specified based on sources    57969
# Name: english_name, dtype: int64
# ********************
# region is mecklenburg-vorpommern-gov_attrib
# num of have type is 1114612, num of non have type is 10558, ratio of have type is 0.9906165290578313
# num of residential is 0, num of non-residential is 0, ratio of residential is 0.0
# Series([], Name: english_name, dtype: int64)
# ********************
# region is niedersachsen-gov_attrib
# num of have type is 6795253, num of non have type is 4, ratio of have type is 0.9999994113541254
# num of residential is 2455137, num of non-residential is 3489945, ratio of residential is 0.36130177934508106
# Business or commercial buildings              2954203
# residential building                          2354024
# Agricultural and forestry company building     245716
# Commercial and industrial buildings             83460
# building for supply                             62986
#                                                ...
# castle, fortress                                   36
# concert building                                   25
# Operating building for the cable car               22
# station building                                   19
# Parliament                                         10
# Name: english_name, Length: 67, dtype: int64
# ********************
# region is nordrhein-westfalen-gov_attrib
# num of have type is 10713759, num of non have type is 0, ratio of have type is 1.0
# num of residential is 4397670, num of non-residential is 5147240, ratio of residential is 0.41046937867465566
# residential house                   3878330
# Garage                              2311558
# Business or commercial buildings     470672
# shed                                 416547
# garden house                         270735
#                                      ...
# pumping station                           7
# weather station                           6
# plant show house                          4
# district government                       4
# Shipping reception building               1
# Name: english_name, Length: 227, dtype: int64
# ********************
# region is sachsen-anhalt-gov_attrib
# num of have type is 1746707, num of non have type is 0, ratio of have type is 1.0
# num of residential is 1478230, num of non-residential is 268477, ratio of residential is 0.8462953431800525
# residential building                                   1475885
# Business or commercial buildings                        223691
# buildings for recreational purposes                       7710
# buildings for social purposes                             6906
# buildings for public purposes                             3151
# fire Department                                           2605
# church                                                    2336
# Mixed use building with housing                           2207
# Healthcare buildings                                      2014
# cemetery building                                         1969
# General secondary school                                  1880
# hothouse, greenhouse                                      1730
# administration building                                   1677
# shopping mall                                             1497
# Pump station                                              1445
# sports, gym                                               1199
# Building for education and research                       1034
# barracks                                                   860
# buildings for cultural purposes                            835
# hospital                                                   722
# Gas station                                                582
# chapel                                                     524
# Museum                                                     504
# University building (technical college, university)        373
# Schloss                                                    322
# police                                                     256
# Rathaus                                                    242
# reception building                                         228
# castle, fortress                                           224
# research institute                                         178
# water tank                                                 155
# road maintenance                                           148
# house of worship                                           147
# correctional facility                                      142
# Forsthaus                                                  138
# windmill                                                   133
# library, library                                           130
# parking garage                                             130
# watermill                                                   95
# Jugendherberge                                              94
# underground car park                                        90
# dish                                                        84
# theatre, opera                                              76
# indoor pool                                                 76
# Sanatorium                                                  73
# Hut (with accommodation)                                    54
# Messehalle                                                  43
# shelter                                                     32
# radio, television                                           27
# pumping station                                             19
# weather station                                             19
# concert building                                            11
# Parliament                                                   5
# Name: english_name, dtype: int64
# ********************
# region is sachsen-gov_attrib
# num of have type is 2066177, num of non have type is 0, ratio of have type is 1.0
# num of residential is 129, num of non-residential is 2066048, ratio of residential is 6.243414770370592e-05
# Cannot be specified based on sources                   1918072
# Business or commercial buildings                         96265
# Garage                                                   21903
# Stall                                                     5826
# hothouse, greenhouse                                      3523
# General secondary school                                  3263
# church                                                    2227
# fire Department                                           2107
# sports, gym                                               1883
# hospital                                                  1778
# Museum                                                     930
# administration building                                    903
# shelter                                                    868
# University building (technical college, university)        735
# Rathaus                                                    694
# place of leisure and entertainment                         678
# water tank                                                 630
# shopping mall                                              567
# Schloss                                                    516
# chapel                                                     490
# police                                                     350
# pub, restaurant                                            273
# barracks                                                   228
# Hotel, Motel, Pension                                      193
# parking garage                                             173
# Forsthaus                                                  128
# indoor pool                                                128
# Jugendherberge                                             126
# correctional facility                                      117
# windmill                                                   103
# castle, fortress                                            97
# dish                                                        76
# Tourist information center                                  75
# theatre, opera                                              68
# watermill                                                   55
# Messehalle                                                  42
# house of worship                                            26
# Sanatorium                                                  16
# pumping station                                             16
# Aquarium, terrarium, aviary                                 15
# radio, television                                           11
# Parliament                                                   2
# residential building                                         1
# Name: english_name, dtype: int64
# ********************
# region is thuerigen-gov_attrib
# num of have type is 2250018, num of non have type is 0, ratio of have type is 1.0
# num of residential is 878966, num of non-residential is 1266488, ratio of residential is 0.3906484303681126
# residential building                    867487
# Cannot be specified based on sources    855895
# Recreational buildings                  175716
# Business or commercial buildings        111997
# Garage                                   45047
#                                          ...
# Zollamt                                      4
# Hut (with accommodation)                     4
# pumping station                              4
# synagogue                                    3
# mosque                                       1
# Name: english_name, Length: 72, dtype: int64
# ********************

# %% [markdown]
# # mecklenburg-vorpommern-gov_attrib

# %%
map_dictionary = pd.read_csv(r"D:\Nicola project\Nicola project\mapping\residential.csv")
map_dictionary = map_dictionary.drop(columns = ['Unnamed: 0'])

# %%
map_dictionary
# Out:
#                                         type  code  \
# 0                                Wohngebäude  1000
# 1                                   Wohnhaus  1010
# 2                                   Wohnheim  1020
# 3                                 Kinderheim  1021
# 4                               Seniorenheim  1022
# ..                                       ...   ...
# 227                        Pflanzenschauhaus  3273
# 228  Gebäude für andere Erholungseinrichtung  3280
# 229                              Schutzhütte  3281
# 230        Touristisches Informationszentrum  3290
# 231  Nach Quellenlage nicht zu spezifizieren  9998
#
#                                  german_name  \
# 0                                Wohngebäude
# 1                                   Wohnhaus
# 2                                   Wohnheim
# 3                                 Kinderheim
# 4                               Seniorenheim
# ..                                       ...
# 227                        Pflanzenschauhaus
# 228  Gebäude für andere Erholungseinrichtung
# 229                              Schutzhütte
# 230        Touristisches Informationszentrum
# 231  Nach Quellenlage nicht zu spezifizieren
#
#                                english_name  residential
# 0                      residential building         True
# 1                         residential house         True
# 2                                      dorm        False
# 3                           children's home        False
# 4                           retirement home        False
# ..                                      ...          ...
# 227                        plant show house        False
# 228  Building for other recreation facility        False
# 229                                 shelter        False
# 230              Tourist information center        False
# 231    Cannot be specified based on sources        False
#
# [232 rows x 5 columns]

# %%
data = pd.read_csv(r"D:\Nicola project\Nicola project\mapping\jiawei\mecklenburg-vorpommern-gov_attrib\mecklenburg-vorpommern-gov_attrib.csv")

# %%
data
# Out:
#                                 id  height  \
# 0        Building_DEMVAL73000ACsBp   3.379
# 1        Building_DEMVAL73000Asceu   9.300
# 2        Building_DEMVAL73000ACsyv   5.381
# 3        Building_DEMVAL73000Ascez   2.731
# 4        Building_DEMVAL73000ACsBd   9.520
# ...                            ...     ...
# 1125165  Building_DEMVAL75000cfdEt   7.209
# 1125166  Building_DEMVAL75000sggBb   5.196
# 1125167  Building_DEMVAL75000sggAE   7.072
# 1125168  Building_DEMVAL75000GcuxA   6.207
# 1125169  Building_DEMVAL75000sggDt   4.433
#
#                                                type_source  type  age  floors  \
# 0        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 2        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 3        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 4        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# ...                                                    ...   ...  ...     ...
# 1125165  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1125166  https://registry.gdi-de.org/id/de.____/versorg...   NaN  NaN     NaN
# 1125167  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1125168  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1125169  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
#
#                         source_file
# 0        lod2_33_386_6020_2_inspire
# 1        lod2_33_386_6020_2_inspire
# 2        lod2_33_386_6020_2_inspire
# 3        lod2_33_386_6020_2_inspire
# 4        lod2_33_386_6020_2_inspire
# ...                             ...
# 1125165  lod2_33_452_5924_2_inspire
# 1125166  lod2_33_452_5924_2_inspire
# 1125167  lod2_33_452_5924_2_inspire
# 1125168  lod2_33_452_5924_2_inspire
# 1125169  lod2_33_452_5924_2_inspire
#
# [1125170 rows x 7 columns]

# %%
data_copy = data.dropna(subset=['type_source']).copy()
data_copy
# Out:
#                                 id  height  \
# 0        Building_DEMVAL73000ACsBp   3.379
# 1        Building_DEMVAL73000Asceu   9.300
# 2        Building_DEMVAL73000ACsyv   5.381
# 3        Building_DEMVAL73000Ascez   2.731
# 4        Building_DEMVAL73000ACsBd   9.520
# ...                            ...     ...
# 1125165  Building_DEMVAL75000cfdEt   7.209
# 1125166  Building_DEMVAL75000sggBb   5.196
# 1125167  Building_DEMVAL75000sggAE   7.072
# 1125168  Building_DEMVAL75000GcuxA   6.207
# 1125169  Building_DEMVAL75000sggDt   4.433
#
#                                                type_source  type  age  floors  \
# 0        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 2        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 3        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 4        http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# ...                                                    ...   ...  ...     ...
# 1125165  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1125166  https://registry.gdi-de.org/id/de.____/versorg...   NaN  NaN     NaN
# 1125167  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1125168  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
# 1125169  http://inspire.ec.europa.eu/codelist/CurrentUs...   NaN  NaN     NaN
#
#                         source_file
# 0        lod2_33_386_6020_2_inspire
# 1        lod2_33_386_6020_2_inspire
# 2        lod2_33_386_6020_2_inspire
# 3        lod2_33_386_6020_2_inspire
# 4        lod2_33_386_6020_2_inspire
# ...                             ...
# 1125165  lod2_33_452_5924_2_inspire
# 1125166  lod2_33_452_5924_2_inspire
# 1125167  lod2_33_452_5924_2_inspire
# 1125168  lod2_33_452_5924_2_inspire
# 1125169  lod2_33_452_5924_2_inspire
#
# [1114612 rows x 7 columns]

# %%
def typesource(x):
    
    lst2 = []
    for i in x:
        a = i.split('/')[-1]
        lst2.append(a)
    return(lst2)

# %%
data_copy['type_source'] = typesource(data_copy['type_source'])

# %%
data_copy
# Out:
#                                 id  height           type_source  type  age  \
# 0        Building_DEMVAL73000ACsBp   3.379           agriculture   NaN  NaN
# 1        Building_DEMVAL73000Asceu   9.300           residential   NaN  NaN
# 2        Building_DEMVAL73000ACsyv   5.381           agriculture   NaN  NaN
# 3        Building_DEMVAL73000Ascez   2.731           agriculture   NaN  NaN
# 4        Building_DEMVAL73000ACsBd   9.520           residential   NaN  NaN
# ...                            ...     ...                   ...   ...  ...
# 1125165  Building_DEMVAL75000cfdEt   7.209           residential   NaN  NaN
# 1125166  Building_DEMVAL75000sggBb   5.196  versorgungEntsorgung   NaN  NaN
# 1125167  Building_DEMVAL75000sggAE   7.072        publicServices   NaN  NaN
# 1125168  Building_DEMVAL75000GcuxA   6.207           agriculture   NaN  NaN
# 1125169  Building_DEMVAL75000sggDt   4.433           residential   NaN  NaN
#
#          floors                 source_file
# 0           NaN  lod2_33_386_6020_2_inspire
# 1           NaN  lod2_33_386_6020_2_inspire
# 2           NaN  lod2_33_386_6020_2_inspire
# 3           NaN  lod2_33_386_6020_2_inspire
# 4           NaN  lod2_33_386_6020_2_inspire
# ...         ...                         ...
# 1125165     NaN  lod2_33_452_5924_2_inspire
# 1125166     NaN  lod2_33_452_5924_2_inspire
# 1125167     NaN  lod2_33_452_5924_2_inspire
# 1125168     NaN  lod2_33_452_5924_2_inspire
# 1125169     NaN  lod2_33_452_5924_2_inspire
#
# [1114612 rows x 7 columns]

# %%
lst3 = []
for i in data_copy['type_source']:
    lst3.append(('residential' in i)|('Residential' in i)|('Mixed use building with housing' in i)\
               |('farmhouse' in i)|('Forsthaus' in i)|('Ferienhaus'in i)|('weekend house' in i)\
               |('Building for trade and services with housing'in i)\
               |('Building for trade and industry with living' in i))
data_copy['residential'] = lst3

# %%
data_copy
# Out:
#                                 id  height           type_source  type  age  \
# 0        Building_DEMVAL73000ACsBp   3.379           agriculture   NaN  NaN
# 1        Building_DEMVAL73000Asceu   9.300           residential   NaN  NaN
# 2        Building_DEMVAL73000ACsyv   5.381           agriculture   NaN  NaN
# 3        Building_DEMVAL73000Ascez   2.731           agriculture   NaN  NaN
# 4        Building_DEMVAL73000ACsBd   9.520           residential   NaN  NaN
# ...                            ...     ...                   ...   ...  ...
# 1125165  Building_DEMVAL75000cfdEt   7.209           residential   NaN  NaN
# 1125166  Building_DEMVAL75000sggBb   5.196  versorgungEntsorgung   NaN  NaN
# 1125167  Building_DEMVAL75000sggAE   7.072        publicServices   NaN  NaN
# 1125168  Building_DEMVAL75000GcuxA   6.207           agriculture   NaN  NaN
# 1125169  Building_DEMVAL75000sggDt   4.433           residential   NaN  NaN
#
#          floors                 source_file  residential
# 0           NaN  lod2_33_386_6020_2_inspire        False
# 1           NaN  lod2_33_386_6020_2_inspire         True
# 2           NaN  lod2_33_386_6020_2_inspire        False
# 3           NaN  lod2_33_386_6020_2_inspire        False
# 4           NaN  lod2_33_386_6020_2_inspire         True
# ...         ...                         ...          ...
# 1125165     NaN  lod2_33_452_5924_2_inspire         True
# 1125166     NaN  lod2_33_452_5924_2_inspire        False
# 1125167     NaN  lod2_33_452_5924_2_inspire        False
# 1125168     NaN  lod2_33_452_5924_2_inspire        False
# 1125169     NaN  lod2_33_452_5924_2_inspire         True
#
# [1114612 rows x 8 columns]

# %%
num_residential = len(data_copy[data_copy['residential'] == True])
num_non_residential = (len(data_copy[data_copy['residential'] == False]))
ratio_of_residential = len(data_copy[data_copy['residential'] == True])/len(data_copy['residential'])
print('num of residential is {}, num of non-residential is {}, ratio of residential is {} '.format(num_residential,num_non_residential,ratio_of_residential))

a = data_copy['type_source'].value_counts()   # Count the number of type
print(a)
print('********************')
# Out:
# num of residential is 467235, num of non-residential is 647377, ratio of residential is 0.41919071389864815
# residential                467235
# agriculture                234494
# commerceAndServices        224789
# verkehr                    121365
# industrie                   21920
# publicServices              16475
# versorgungEntsorgung        15128
# industrial                   4593
# office                       4295
# trade                        3732
# residenceForCommunities       586
# Name: type_source, dtype: int64
# ********************
